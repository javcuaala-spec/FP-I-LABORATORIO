# %% [markdown]
# ## Fundamentos de Programación 1
# ### Ingeniería Informática - Inteligencia Artificial (Universidad de Sevilla)
# ---
# # 📘 Ejercicios del Tema 2: Elementos básicos de Python
#
# _Instrucciones_:
# - Para ejercicios de **implementación**, lee cada enunciado y usa la **celda de código** que sigue para contestar.
# - Para ejercicios de **traza**, trata de averiguar el resultado antes de ejecutar la celda con el código.
# - Para **corrección**, la primera celda de código contiene el código con errores; usa la celda siguiente para tu versión corregida.

# %% [markdown]
# ### Ejercicio 1
# **[Implementación]**
# Escribe un programa que muestre un saludo personalizado y el resultado de una suma.
# Pasos:
# 1. Inicializa dos variables: nombre (str) y n (int).
# 2. Muestra "Hola, " seguido del nombre.
# 3. Muestra "La suma de 2 y n es: " seguido de 2 + n.

# %%
# Escribe tu solución aquí
nombre= input("Introduce tu nombre: ")
suma = 2 + 2
print("Hola", nombre, "La suma de 2 más 2 es", suma)
# Out:
# Hola Javier La suma de 2 más 2 es 4

# %% [markdown]
# ### Ejercicio 2
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado que se obtiene en pantalla.

# %%
print("Comienzo")
x = 3
print(x)
x = x + 2
print("Fin:", x)

'''
RESULTADO ESPERADO:5

'''
# Out:
# Comienzo
# 3
# Fin: 5
# '\nRESULTADO ESPERADO:5\n\n'

# %% [markdown]
# ### Ejercicio 3
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
nombre = "Ana"
edad = "20"
print("Me llamo " + nombre + " y tengo " + edad + " años.")
print("El año que viene tendré: " + edad + 1)

# %%
# Tu versión corregida aquí
nombre = "Ana"
edad = 20
print("Hola, me llamo", nombre ,"y tengo", edad ,"años.")
print("Eso quiere decir que el año que viene tendré", edad+1 ,"años.")
# Out:
# Hola, me llamo Ana y tengo 20 años.
# Eso quiere decir que el año que viene tendré 21 años.

# %% [markdown]
# ### Ejercicio 4
# **[Implementación]**
# Calcula el Índice de Masa Corporal $IMC = peso/altura^2$ y muéstralo con 2 decimales.
#
# Pasos:
# 1. Define peso (float) y altura (float).
# 2. Calcula imc.
# 3. Muestra "IMC: <valor_con_2_decimales>".

# %%
# Escribe tu solución aquí
peso=float(input("Introduce tu peso en kg: "))
altura=float(input("Introduce tu altura en metros: "))
imc=peso/(altura**2)
imc=round(imc,2)
print("TU imc es: ", imc)
# Out:
# TU imc es:  14.79

# %% [markdown]
# ### Ejercicio 5
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
a = 7
b = 2
c = a / b
d = a // b
e = a % b
print(type(c), c)
print(type(d), d)
print(type(e), e)
'''
RESULTADO ESPERADO: 

'''
# Out:
# <class 'float'> 3.5
# <class 'int'> 3
# <class 'int'> 1
# '\nRESULTADO ESPERADO: \n\n'

# %% [markdown]
# ### Ejercicio 6
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
a = "10"
b = "3,5"
suma = a + b
print("Suma:", suma)

# %%
# Tu versión corregida aquí
a = 10
b = 3.5
suma = a + b
print("suma: ", suma)
# Out:
# suma:  13.5

# %% [markdown]
# ### Ejercicio 7
# **[Implementación]**
# Pide tres valores numéricos y muestra: media, mayor, y si todos son positivos.

# %%
# Escribe tu solución aquí
valor1= float(input("Introduce el primer valor: "))
valor2= float(input("Introduce el segundo valor: "))
valor3= float(input("Introduce el tercer valor: "))
media=(valor1+valor2+valor3)/3
mayor=max(valor1,valor2,valor3)
print(media)
print(mayor)
# Out:
# 3.3333333333333335
# 5.0

# %% [markdown]
# ### Ejercicio 8
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
r = 3 + 4 * 2 > 10 or not(5 - 5 == 0)
print(r)
'''
RESULTADO ESPERADO:False

'''
# Out:
# False
# '\nRESULTADO ESPERADO:False\n\n'

# %% [markdown]
# ### Ejercicio 9
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
edad = 21
altura = 1.75

# Se permite la entrada a la atracción si se da una de estas circunstancias:
# - la edad es mayor o igual a 18 años
# - la edad es mayor o igual a 8 años y la altura es mayor o igual a 1.40 metros
permitir_entrada = edad >= 18 or edad >= 8 and altura >= 1.40

# %%
# Tu versión corregida aquí

edad = 21
altura = 1.75

if edad >=18 or (edad>= 8 and altura<1.40):
   
    print("Puede pasar")
else:
    print("No puede pasar")
# Out:
# Puede pasar

# %% [markdown]
# ### Ejercicio 10
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
total = 0
total2 = total + 5
total = total - 2
total = total2 * 3
print(total)
'''
RESULTADO ESPERADO:15

'''
# Out:
# 15
# '\nRESULTADO ESPERADO:15\n\n'

# %% [markdown]
# ### Ejercicio 11
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
x = 10
y = 20
# Intercambiamos los valores de x e y
x2 = y
y2 = x
print(x2, y2)
# Out:
# 20 10

# %%
# Tu versión corregida aquí

# %% [markdown]
# ### Ejercicio 12
# **[Implementación]**
# Pide un total (float) y un porcentaje de propina (int) y muestra un mensaje "La propina es PROPINA y el total a pagar es TOTAL_A_PAGAR".

# %%
# Escribe tu solución aquí
precio = float(input("Introduzca el total a pagar: "))
propina= int(input("Intrduce un porcentaje de propina."))
propina= precio * (propina/100)
round(propina, 2)
print(f"La propina es: {propina} € y el total a pagar es: {precio} € ")
# Out:
# La propina es: 20.0 € y el total a pagar es: 100.0 €

# %% [markdown]
# ### Ejercicio 13
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
x = input("Número 1: ") # Supongamos que el usuario introduce 3
y = input("Número 2: ") # Supongamos que el usuario introduce 5
print("Suma:", int(x) + int(y))
'''
RESULTADO ESPERADO: 8

'''
# Out:
# Suma: 8
# '\nRESULTADO ESPERADO: 8\n\n'

# %% [markdown]
# ### Ejercicio 14
# **[Implementación]**
# Escribe una expresión para averiguar si la primera y la última cifra de `n` son iguales.

# %%
n = 13321
n = str(n)
if n[0]==n[-1]:
    print("número igual")
# Escribe tu solución aquí
# Out:
# número igual

# %% [markdown]
# ### Ejercicio 15
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
n = 7
print(n % 2 == 0)
print(not (n % 2 == 1))
'''
RESULTADO ESPERADO:False

'''
# Out:
# False
# False
# '\nRESULTADO ESPERADO:False\n\n'

# %% [markdown]
# ### Ejercicio 16
# **[Implementación]**
# Lee un texto desde el teclado y muestra cuántas vocales tiene. Hazlo SIN USAR bucles.

# %%
# Escribe tu solución aquí
#palabra= input("Introduce una palabra: ")
#a=palabra.count("a")
#e=palabra.count("e")
#i=palabra.count("i")
#o=palabra.count("o")
#u=palabra.count("u")

#vocales= a + e + i + o + u

#print(vocales)
palabra= input("Introduce una palabra: ")
vocales= ["a","e","i","o","u"]
contador=0
for i in palabra:
    contador=contador+1
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ### Ejercicio 17
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
print("python".upper())
print("  Fundamentos de Programación 1  ".strip())
print("uno-dos-tres".split("-"))
print("abc".find("b"))
print("abc".find("d"))
'''
RESULTADO ESPERADO:

'''
# Out:
# PYTHON
# Fundamentos de Programación 1
# ['uno', 'dos', 'tres']
# 1
# -1
# '\nRESULTADO ESPERADO:\n\n'

# %% [markdown]
# ### Ejercicio 18
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
s = "Hola"
s.replace("o","0")
s.upper()
print(s) # H0LA
# Out:
# Hola

# %%
# Tu versión corregida aquí
s = "hola"
s1=s.replace("o","0")
print(s1.upper())
# Out:
# H0LA

# %% [markdown]
# ### Ejercicio 19
# **[Implementación]**
# Pide una nota de 0 a 10 al usuario y muestra un mensaje indicando SUSPENSO, APROBADO, NOTABLE o SOBRESALIENTE.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 20
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
x = 8
if x > 3:
    print('A')
elif x >= 8:
    print('B')
else:
    print('C')

'''
RESULTADO ESPERADO:

'''

# %% [markdown]
# ### Ejercicio 21
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
n = 65

# Muestra "baja", "alta" o "muy alta" en función del valor de n
if n >= 50: 
    print('alta')
if n >= 70: 
    print('muy alta')
else: 
    print('baja')

# %%
# Tu versión corregida aquí

# %% [markdown]
# ### Ejercicio 22
# **[Implementación]**
# Escribe un programa que pida al usuario una contraseña y siga pidiéndola hasta que escriba la correcta ("python123"). Al acertar, muestra "Acceso concedido".

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 23
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
i = 16
j = 0
while i > 1:
    i /= 2
    j += 1
print(j)
'''
RESULTADO ESPERADO:

'''

# %% [markdown]
# ### Ejercicio 24
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
x = 5
# Muestra los números del 5 al 9 (incluido)
while x < 10:
    print(x)

# %%
# Tu versión corregida aquí

# %% [markdown]
# ### Ejercicio 25
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
for n in range(3, 10):
    if n % 2 == 0:
        print('par:', n)
    break
print('fin')
'''
RESULTADO ESPERADO:

'''

# %% [markdown]
# ### Ejercicio 26
# **[Implementación]**
# Pide N y calcula la suma 1..N.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ### Ejercicio 27
# **[Traza]**
# Realiza la traza del siguiente código y anota el resultado final.

# %%
for x in range(10, 0, -3):
    print(x)
'''
RESULTADO ESPERADO:

'''

# %% [markdown]
# ### Ejercicio 28
# **[Corrección de errores]**
# El siguiente código contiene errores. Corrígelo en la celda posterior.

# %%
texto = "programación"
tam = len(texto)
# Muestra cada carácter del texto en una línea diferente
for i in range(1, len(texto)+1):
    print(texto[i])

# %%
# Tu versión corregida aquí

# %% [markdown]
# ### Ejercicio 29
# **[Implementación]** Analizador de texto simple
#
# **Objetivo:** Dado un texto, calcula el porcentaje de dígitos y vocales que contiene, y comprueba qué posición ocupa una palabra clave.
#
# **Pasos:**
# 1. Lee el texto.
# 2. Recorre carácter a carácter incrementando contadores.
# 4. Calcula porcentajes y muéstralos con dos decimales.
# 5. Lee la palabra clave.
# 6. Muestra en qué posición aparece dicha palabra clave, o indica que no se encuentra en el texto.
#
# Ejemplo de salida:
# ```
# Texto: "Python 3 es genial!"
#
# Porcentaje de dígitos: 5.26%
# Porcentaje de vocales: 26.32%
#
# Palabra clave: "genial"
# Posición: 12
# ```

# %%
# Implementa tu solución aquí

# %% [markdown]
# ### Ejercicio 30
# **[Implementación]** Calculadora de notas con etiqueta
#
# **Objetivo:** Lee teoría y laboratorio, calcula media ponderada y etiqueta (Suspenso/Aprobado/Notable/Sobresaliente).
#
# **Pasos:**
# 1. Lee porcentajes de ponderación como enteros (ej. 70 y 30).
# 2. Lee nota_teoria (float) y nota_lab (float).
# 3. Calcula la nota final.
# 5. Muestra un mensaje del estilo 'Final: 7.80 → Notable'.

# %%
# Implementa tu solución aquí

# %% [markdown]
# ### Ejercicio 31
# **[Implementación]** Cálculo de billetes y monedas
#
# **Objetivo**: Calcular cuántos billetes y monedas de cada valor debemos devolver para una cantidad determinada.
#
# **Pasos:**
#
# 1. Lee la cantidad total a devolver (float).
# 2. Define una lista con los valores de billetes y monedas disponibles (ej. ).
# 3. Para cada valor de billete o moneda (50, 20, 10, 5, 2, 1, 0.5, 0.2, 0.1, 0.05, 0.02, 0.01), calcula cuántos billetes/monedas se pueden devolver y actualiza la cantidad restante.
# 4. Muestra el número de billetes/monedas de cada valor.
#
# NOTA: Puedes recorrer los distintos valores de billete o moneda así:
# ```python
# for valor in 50, 20, 10, 5, 2, 1, 0.5, 0.2, 0.1, 0.05, 0.02, 0.01:
#     ...
# ```

# %%
# Implementa tu solución aquí
